# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import pandas as pd
from tensorflow.keras import layers
from tqdm import tqdm
import matplotlib.pyplot as plt
import pathlib
import os

AUTOTUNE = tf.data.experimental.AUTOTUNE
tf.keras.backend.clear_session()  # For easy reset of notebook state.

tf.__version__
tf.executing_eagerly()
# Out:
# True

# %%
ds = tfds.load(name="imagenette", with_info=True, split=["train[:1000]","validation[:100]"])
ds_train=ds[0][0]
ds_test=ds[0][1]
assert isinstance(ds_train, tf.data.Dataset)

def normalize(x):
    y = {'image': tf.image.convert_image_dtype(x['image'], tf.float32), 'label': x['label']}
    y = (tf.image.resize(y['image'], (224,224)), y['label'])
    return y
    
ds_train = ds_train.map(lambda x: normalize(x))
ds_train = ds_train.cache()
ds_train = ds_train.shuffle(100)
ds_train = ds_train.batch(4)
ds_train = ds_train.prefetch(tf.data.experimental.AUTOTUNE)

ds_test = ds_test.map(
    normalize, num_parallel_calls=tf.data.experimental.AUTOTUNE)
ds_test = ds_test.batch(4)
ds_test = ds_test.cache()
ds_test = ds_test.prefetch(tf.data.experimental.AUTOTUNE)

# %%
class ResNetBlock(tf.keras.layers.Layer):
    def __init__(self, filters=64, stride=1):
        super(ResNetBlock, self).__init__()
        self.stride = stride
        self.conv1 = layers.Conv2D(filters, 3, strides=(self.stride, self.stride), activation='relu', padding='same')
        self.bn1 = layers.BatchNormalization()
        self.conv2 = layers.Conv2D(filters, 3, padding='same')
        self.bn2 = layers.BatchNormalization()
        if stride == 2:
            self.conv3 = layers.Conv2D(filters,1, strides=(self.stride, self.stride), padding='same' )
            self.bn3 = layers.BatchNormalization()
        self.add1 = layers.Add()
    
    def call(self, inputs, training=False):
        print('inputs', inputs)
        x = self.conv1(inputs)
        x = self.bn1(x, training=training)
        print('conv1', x)
        x = self.conv2(x)
        x = self.bn2(x, training=training)
        print('conv2', x)
        if self.stride == 2:
            inputs = self.conv3(x)
            inputs = self.bn3(x)
            print('conv3', inputs)
        return tf.nn.relu(self.add1([x, inputs]))
    

class CustomResNetModel(tf.keras.Model):
    def __init__(self):
        super(CustomResNetModel, self).__init__()
        self.conv1 = layers.Conv2D(64, 7, strides=(2, 2), padding='same')
        self.pool1 = layers.MaxPool2D(pool_size=(3,3), strides=(2,2), padding='same')
        self.res_block1 = ResNetBlock(64)
        self.res_block2 = ResNetBlock(64)
        self.res_block3 = ResNetBlock(64)
        self.res_block4 = ResNetBlock(128, 2)
        self.res_block5 = ResNetBlock(128)
        self.res_block6 = ResNetBlock(128)
        self.res_block7 = ResNetBlock(128)
        self.res_block8 = ResNetBlock(256, 2)
        self.res_block9 = ResNetBlock(256)
        self.res_block10 = ResNetBlock(256)
        self.res_block11 = ResNetBlock(256)
        self.res_block12 = ResNetBlock(256)
        self.res_block13 = ResNetBlock(256)
        self.res_block14 = ResNetBlock(512, 2)
        self.res_block15 = ResNetBlock(512)
        self.res_block16 = ResNetBlock(512)
        self.pool2 = layers.GlobalAveragePooling2D()
        self.dense1 = layers.Dense(1000, activation='relu')
        self.dense2 = layers.Dense(100, activation='softmax')

    def call(self,inputs):
        #print('inputs',inputs)
        x = self.conv1(inputs)
        #print('after conv',x)
        x = self.pool1(x)
        #print('after pool',x)
        x = self.res_block1(x)
        #print('after resblock 1',x)
        x = self.res_block2(x)
        #print('after resblock 2',x)
        x = self.res_block3(x)
        #print('after resblock 3',x)
        x = self.res_block4(x)
        #print('after resblock 4',x)
        x = self.res_block5(x)
        x = self.res_block6(x)
        x = self.res_block7(x)
        x = self.res_block8(x)
        x = self.res_block9(x)
        x = self.res_block10(x)
        x = self.res_block11(x)
        x = self.res_block12(x)
        x = self.res_block13(x)
        x = self.res_block14(x)
        x = self.res_block15(x)
        x = self.res_block16(x)
        x = self.pool2(x)
        x = self.dense1(x)
        
        return self.dense2(x)

# %%
model = CustomResNetModel()

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(0.001),
    metrics=['accuracy'],
)

# %%
model.fit(
    x=ds_train,
    #steps_per_epoch=1,
    epochs=15,
    validation_data=ds_test,
)
model.run_eagerly = True
# Out:
# inputs Tensor("custom_res_net_model_23/max_pooling2d_23/Identity:0", shape=(None, 56, 56, 64), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_296/batch_normalization_599/Identity:0", shape=(None, 56, 56, 64), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_296/batch_normalization_600/Identity:0", shape=(None, 56, 56, 64), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_296/Identity:0", shape=(None, 56, 56, 64), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_297/batch_normalization_601/Identity:0", shape=(None, 56, 56, 64), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_297/batch_normalization_602/Identity:0", shape=(None, 56, 56, 64), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_297/Identity:0", shape=(None, 56, 56, 64), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_298/batch_normalization_603/Identity:0", shape=(None, 56, 56, 64), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_298/batch_normalization_604/Identity:0", shape=(None, 56, 56, 64), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_298/Identity:0", shape=(None, 56, 56, 64), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_299/batch_normalization_605/Identity:0", shape=(None, 28, 28, 128), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_299/batch_normalization_606/Identity:0", shape=(None, 28, 28, 128), dtype=float32)
# conv3 Tensor("custom_res_net_model_23/res_net_block_299/batch_normalization_607/Identity:0", shape=(None, 28, 28, 128), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_299/Identity:0", shape=(None, 28, 28, 128), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_300/batch_normalization_608/Identity:0", shape=(None, 28, 28, 128), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_300/batch_normalization_609/Identity:0", shape=(None, 28, 28, 128), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_300/Identity:0", shape=(None, 28, 28, 128), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_301/batch_normalization_610/Identity:0", shape=(None, 28, 28, 128), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_301/batch_normalization_611/Identity:0", shape=(None, 28, 28, 128), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_301/Identity:0", shape=(None, 28, 28, 128), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_302/batch_normalization_612/Identity:0", shape=(None, 28, 28, 128), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_302/batch_normalization_613/Identity:0", shape=(None, 28, 28, 128), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_302/Identity:0", shape=(None, 28, 28, 128), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_303/batch_normalization_614/Identity:0", shape=(None, 14, 14, 256), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_303/batch_normalization_615/Identity:0", shape=(None, 14, 14, 256), dtype=float32)
# conv3 Tensor("custom_res_net_model_23/res_net_block_303/batch_normalization_616/Identity:0", shape=(None, 14, 14, 256), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_303/Identity:0", shape=(None, 14, 14, 256), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_304/batch_normalization_617/Identity:0", shape=(None, 14, 14, 256), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_304/batch_normalization_618/Identity:0", shape=(None, 14, 14, 256), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_304/Identity:0", shape=(None, 14, 14, 256), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_305/batch_normalization_619/Identity:0", shape=(None, 14, 14, 256), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_305/batch_normalization_620/Identity:0", shape=(None, 14, 14, 256), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_305/Identity:0", shape=(None, 14, 14, 256), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_306/batch_normalization_621/Identity:0", shape=(None, 14, 14, 256), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_306/batch_normalization_622/Identity:0", shape=(None, 14, 14, 256), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_306/Identity:0", shape=(None, 14, 14, 256), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_307/batch_normalization_623/Identity:0", shape=(None, 14, 14, 256), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_307/batch_normalization_624/Identity:0", shape=(None, 14, 14, 256), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_307/Identity:0", shape=(None, 14, 14, 256), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_308/batch_normalization_625/Identity:0", shape=(None, 14, 14, 256), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_308/batch_normalization_626/Identity:0", shape=(None, 14, 14, 256), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_308/Identity:0", shape=(None, 14, 14, 256), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_309/batch_normalization_627/Identity:0", shape=(None, 7, 7, 512), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_309/batch_normalization_628/Identity:0", shape=(None, 7, 7, 512), dtype=float32)
# conv3 Tensor("custom_res_net_model_23/res_net_block_309/batch_normalization_629/Identity:0", shape=(None, 7, 7, 512), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_309/Identity:0", shape=(None, 7, 7, 512), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_310/batch_normalization_630/Identity:0", shape=(None, 7, 7, 512), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_310/batch_normalization_631/Identity:0", shape=(None, 7, 7, 512), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_310/Identity:0", shape=(None, 7, 7, 512), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_311/batch_normalization_632/Identity:0", shape=(None, 7, 7, 512), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block
dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_298/Relu:0", shape=(None, 56, 56, 64), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_299/batch_normalization_605/FusedBatchNormV3:0", shape=(None, 28, 28, 128), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_299/batch_normalization_606/FusedBatchNormV3:0", shape=(None, 28, 28, 128), dtype=float32)
# conv3 Tensor("custom_res_net_model_23/res_net_block_299/batch_normalization_607/FusedBatchNormV3:0", shape=(None, 28, 28, 128), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_299/Relu:0", shape=(None, 28, 28, 128), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_300/batch_normalization_608/FusedBatchNormV3:0", shape=(None, 28, 28, 128), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_300/batch_normalization_609/FusedBatchNormV3:0", shape=(None, 28, 28, 128), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_300/Relu:0", shape=(None, 28, 28, 128), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_301/batch_normalization_610/FusedBatchNormV3:0", shape=(None, 28, 28, 128), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_301/batch_normalization_611/FusedBatchNormV3:0", shape=(None, 28, 28, 128), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_301/Relu:0", shape=(None, 28, 28, 128), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_302/batch_normalization_612/FusedBatchNormV3:0", shape=(None, 28, 28, 128), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_302/batch_normalization_613/FusedBatchNormV3:0", shape=(None, 28, 28, 128), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_302/Relu:0", shape=(None, 28, 28, 128), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_303/batch_normalization_614/FusedBatchNormV3:0", shape=(None, 14, 14, 256), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_303/batch_normalization_615/FusedBatchNormV3:0", shape=(None, 14, 14, 256), dtype=float32)
# conv3 Tensor("custom_res_net_model_23/res_net_block_303/batch_normalization_616/FusedBatchNormV3:0", shape=(None, 14, 14, 256), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_303/Relu:0", shape=(None, 14, 14, 256), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_304/batch_normalization_617/FusedBatchNormV3:0", shape=(None, 14, 14, 256), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_304/batch_normalization_618/FusedBatchNormV3:0", shape=(None, 14, 14, 256), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_304/Relu:0", shape=(None, 14, 14, 256), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_305/batch_normalization_619/FusedBatchNormV3:0", shape=(None, 14, 14, 256), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_305/batch_normalization_620/FusedBatchNormV3:0", shape=(None, 14, 14, 256), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_305/Relu:0", shape=(None, 14, 14, 256), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_306/batch_normalization_621/FusedBatchNormV3:0", shape=(None, 14, 14, 256), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_306/batch_normalization_622/FusedBatchNormV3:0", shape=(None, 14, 14, 256), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_306/Relu:0", shape=(None, 14, 14, 256), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_307/batch_normalization_623/FusedBatchNormV3:0", shape=(None, 14, 14, 256), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_307/batch_normalization_624/FusedBatchNormV3:0", shape=(None, 14, 14, 256), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_307/Relu:0", shape=(None, 14, 14, 256), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_308/batch_normalization_625/FusedBatchNormV3:0", shape=(None, 14, 14, 256), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_308/batch_normalization_626/FusedBatchNormV3:0", shape=(None, 14, 14, 256), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_308/Relu:0", shape=(None, 14, 14, 256), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_309/batch_normalization_627/FusedBatchNormV3:0", shape=(None, 7, 7, 512), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_309/batch_normalization_628/FusedBatchNormV3:0", shape=(None, 7, 7, 512), dtype=float32)
# conv3 Tensor("custom_res_net_model_23/res_net_block_309/batch_normalization_629/FusedBatchNormV3:0", shape=(None, 7, 7, 512), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_309/Relu:0", shape=(None, 7, 7, 512), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_310/batch_normalization_630/FusedBatchNormV3:0", shape=(None, 7, 7, 512), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_310/batch_normalization_631/FusedBatchNormV3:0", shape=(None, 7, 7, 512), dtype=float32)
# inputs Tensor("custom_res_net_model_23/res_net_block_310/Relu:0", shape=(None, 7, 7, 512), dtype=float32)
# conv1 Tensor("custom_res_net_model_23/res_net_block_311/batch_normalization_632/FusedBatchNormV3:0", shape=(None, 7, 7, 512), dtype=float32)
# conv2 Tensor("custom_res_net_model_23/res_net_block_311/batch_normalization_633/FusedBatchNormV3:0", shape=(None, 7, 7, 512), dtype=float32)
# WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net_model_23/res_net_block_299/conv2d_631/kernel:0', 'custom_res_net_model_23/res_net_block_299/conv2d_631/bias:0', 'custom_res_net_model_23/res_net_block_303/conv2d_640/kernel:0', 'custom_res_net_model_23/res_net_block_303/conv2d_640/bias:0', 'custom_res_net_model_23/res_net_block_309/conv2d_653/kernel:0', 'custom_res_net_model_23/res_net_block_309/conv2d_653/bias:0'] when minimizing the loss.
# WARNING:tensorflow:Gradients do not exist for variables ['custom_res_net_model_23/res_net_block_299/conv2d_631/kernel:0', 'custom_res_net_model_23/res_net_block_299/conv2d_631/bias:0', 'custom_res_net_model_23/res_net_block_303/conv2d_640/kernel:0', 'custom_res_net_model_23/res_net_block_303/conv2d_640/bias:0', 'custom_res_net_model_23/res_net_block_309/conv2d_653/kernel:0', 'custom_res_net_model_23/res_net_block_309/conv2d_653/bias:0'] when minimizing the loss.
#      67/Unknown - 98s 1s/step - loss: 3.4019 - accuracy: 0.1212
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-3429c1feb820> in <module>
#       3     #steps_per_epoch=1,
#       4     epochs=15,
# ----> 5     validation_data=ds_test,
#       6 )
#       7 model.run_eagerly = True
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     597       # In this case we have created variables on the first call, so we run the
#     598       # defunned version which is guaranteed to never create variables.
# --> 599       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     600     elif self._stateful_fn is not None:
#     601       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    2361     with self._lock:
#    2362       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2363     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2364
#    2365   @property
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1609          if isinstance(t, (ops.Tensor,
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#    1613   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:
