# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import pandas as pd
from tensorflow.keras import layers
from tqdm import tqdm
import matplotlib.pyplot as plt
import pathlib
import os
import Pipelines.helperfiles.helpers as helpers
from Pipelines.helperfiles.models import VGG11

AUTOTUNE = tf.data.experimental.AUTOTUNE
tf.keras.backend.clear_session()  # For easy reset of notebook state.

tf.__version__
#tf.executing_eagerly()
# Out:
# '2.2.0'

# %%
data = helpers.load_data('cifar10')

# %% [markdown]
# # define model

# %%
data
# Out:
# (<PrefetchDataset shapes: ((None, 32, 32, 3), (None,)), types: (tf.float32, tf.int64)>,
#  <PrefetchDataset shapes: ((None, 32, 32, 3), (None,)), types: (tf.float32, tf.int64)>,
#  <tf.Tensor: shape=(1000, 32, 32, 3), dtype=float32, numpy=
#  array([[[[0.7058824 , 0.7294118 , 0.7411765 ],
#           [0.6313726 , 0.654902  , 0.65882355],
#           [0.54901963, 0.57254905, 0.5568628 ],
#           ...,
#           [0.20392159, 0.21568629, 0.15686275],
#           [0.20000002, 0.21568629, 0.15686275],
#           [0.20000002, 0.21176472, 0.15686275]],
#
#          [[0.6745098 , 0.69803923, 0.6901961 ],
#           [0.5882353 , 0.6117647 , 0.6       ],
#           [0.46274513, 0.4901961 , 0.46274513],
#           ...,
#           [0.1764706 , 0.18431373, 0.12941177],
#           [0.16862746, 0.1764706 , 0.12156864],
#           [0.17254902, 0.18823531, 0.13333334]],
#
#          [[0.6313726 , 0.65882355, 0.627451  ],
#           [0.5764706 , 0.60784316, 0.57254905],
#           [0.47058827, 0.49803925, 0.46274513],
#           ...,
#           [0.16470589, 0.18823531, 0.12941177],
#           [0.16862746, 0.19607845, 0.13333334],
#           [0.18039216, 0.21960786, 0.15294118]],
#
#          ...,
#
#          [[0.97647065, 0.97647065, 0.97647065],
#           [0.9921569 , 0.9921569 , 0.9921569 ],
#           [0.98823535, 0.98823535, 0.98823535],
#           ...,
#           [0.9960785 , 0.9960785 , 0.9960785 ],
#           [1.        , 1.        , 1.        ],
#           [0.9843138 , 0.9843138 , 0.9843138 ]],
#
#          [[0.97647065, 0.97647065, 0.97647065],
#           [0.9921569 , 0.9921569 , 0.9921569 ],
#           [0.98823535, 0.98823535, 0.98823535],
#           ...,
#           [0.9960785 , 0.9960785 , 0.9960785 ],
#           [1.        , 1.        , 1.        ],
#           [0.98823535, 0.98823535, 0.98823535]],
#
#          [[0.97647065, 0.97647065, 0.97647065],
#           [0.9921569 , 0.9921569 , 0.9921569 ],
#           [0.98823535, 0.98823535, 0.98823535],
#           ...,
#           [0.9960785 , 0.9960785 , 0.9960785 ],
#           [1.        , 1.        , 1.        ],
#           [0.9803922 , 0.9803922 , 0.9803922 ]]],
#
#
#         [[[0.454902  , 0.74509805, 0.9843138 ],
#           [0.454902  , 0.7254902 , 0.95294124],
#           [0.42352945, 0.69411767, 0.92549026],
#           ...,
#           [0.18431373, 0.13333334, 0.17254902],
#           [0.18431373, 0.13725491, 0.17254902],
#           [0.7686275 , 0.6901961 , 0.6901961 ]],
#
#          [[0.69411767, 0.5529412 , 0.49803925],
#           [0.75294125, 0.6745098 , 0.65882355],
#           [0.7803922 , 0.70980394, 0.7019608 ],
#           ...,
#           [0.86666673, 0.80392164, 0.79215693],
#           [0.8352942 , 0.7725491 , 0.7803922 ],
#           [0.7686275 , 0.6901961 , 0.69411767]],
#
#          [[0.69803923, 0.5411765 , 0.4666667 ],
#           [0.7843138 , 0.72156864, 0.7019608 ],
#           [0.8470589 , 0.8000001 , 0.7960785 ],
#           ...,
#           [0.8431373 , 0.76470596, 0.7411765 ],
#           [0.8196079 , 0.74509805, 0.7294118 ],
#           [0.77647066, 0.6862745 , 0.67058825]],
#
#          ...,
#
#          [[0.9294118 , 0.91372555, 0.93725497],
#           [0.9215687 , 0.90196085, 0.92549026],
#           [0.8431373 , 0.8196079 , 0.85098046],
#           ...,
#           [0.94117653, 0.92549026, 0.95294124],
#           [0.9215687 , 0.9058824 , 0.9333334 ],
#           [0.9215687 , 0.9058824 , 0.94117653]],
#
#          [[0.9490197 , 0.92549026, 0.95294124],
#           [0.9490197 , 0.9294118 , 0.9490197 ],
#           [0.882353  , 0.8588236 , 0.8941177 ],
#           ...,
#           [0.9490197 , 0.9333334 , 0.9568628 ],
#           [0.94117653, 0.9215687 , 0.9490197 ],
#           [0.9450981 , 0.92549026, 0.9568628 ]],
#
#          [[0.93725497, 0.9176471 , 0.94117653],
#           [0.93725497, 0.9176471 , 0.93725497],
#           [0.89019614, 0.86666673, 0.8980393 ],
#           ...,
#           [0.9450981 , 0.9215687 , 0.9490197 ],
#           [0.9294118 , 0.909804  , 0.93725497],
#           [0.9294118 , 0.909804  , 0.9333334 ]]],
#
#
#         [[[0.5568628 , 0.4039216 , 0.30588236],
#           [0.5647059 , 0.4039216 , 0.3137255 ],
#           [0.427451  , 0.29803923, 0.24313727],
#           ...,
#           [0.28627452, 0.2509804 , 0.24705884],
#           [0.37254903, 0.30980393, 0.29411766],
#           [0.45098042, 0.34901962, 0.29803923]],
#
#          [[0.5921569 , 0.42352945, 0.31764707],
#           [0.4901961 , 0.3529412 , 0.28235295],
#           [0.35686275, 0.26666668, 0.24313727],
#           ...,
#           [0.2509804 , 0.23529413, 0.2509804 ],
#           [0.3529412 , 0.31764707, 0.32156864],
#           [0.4039216 , 0.33333334, 0.30980393]],
#
#          [[0.5529412 , 0.39607847, 0.29411766],
#           [0.41176474, 0.29411766, 0.24313727],
#           [0.34509805, 0.26666668, 0.25490198],
#           ...,
#           [0.23529413, 0.23137257, 0.25490198],
#           [0.32156864, 0.3019608 , 0.32156864],
#           [0.35686275, 0.31764707, 0.3137255 ]],
#
#          ...,
#
#          [[0.37254903, 0.34117648, 0.26666668],
#           [0.29803923, 0.26666668, 0.23529413],
#           [0.40000004, 0.3529412 , 0.2509804 ],
#           ...,
#           [0.32941177, 0.38431376, 0.31764707],
#           [0.31764707, 0.3803922 , 0.31764707],
#         2, 7, 6, 0, 1, 7, 1, 4, 4, 1, 4, 0, 5, 6, 2, 1, 9, 1, 9, 9, 2, 2,
#         0, 7, 6, 4, 5, 9, 2, 0, 4, 0, 3, 9, 8, 8, 7, 5, 0, 3, 8, 5, 7, 4,
#         7, 0, 1, 0, 3, 7, 8, 9, 1, 0, 3, 3, 5, 5, 3, 7, 2, 9, 0, 4, 8, 3,
#         6, 9, 0, 7, 7, 3, 7, 7, 1, 0, 2, 0, 7, 5, 6, 0, 3, 1, 0, 5, 1, 7,
#         3, 6, 2, 2, 8, 2, 3, 2, 7, 6, 3, 9, 1, 3, 6, 0, 4, 8, 4, 9, 5, 8,
#         9, 3, 7, 1, 0, 2, 1, 4, 0, 7, 6, 5, 1, 3, 7, 1, 3, 9, 7, 1, 1, 3,
#         6, 0, 6, 0, 1, 0, 9, 7, 1, 0, 9, 3, 2, 9, 5, 6, 1, 3, 9, 6, 7, 8,
#         0, 3, 1, 4, 8, 5, 8, 5, 2, 5])>)

# %%
model = VGG11()
adam = tf.keras.optimizers.Adam()

model.compile(optimizer=adam,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'],
             )

# %%
model.fit(
    x=data[0],
    #steps_per_epoch=1,
    epochs=1,
)
# Out:
# 391/391 [==============================] - 11s 27ms/step - loss: 0.9809 - accuracy: 0.6572

# %%
model.summary()
# Out:
# Model: "vg_g11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# custom_conv_layer (CustomCon multiple                  3456
# _________________________________________________________________
# batch_normalization (BatchNo multiple                  256
# _________________________________________________________________
# custom_conv_layer_1 (CustomC multiple                  147456
# _________________________________________________________________
# custom_pool_layer (CustomPoo multiple                  0
# _________________________________________________________________
# batch_normalization_1 (Batch multiple                  512
# _________________________________________________________________
# custom_conv_layer_2 (CustomC multiple                  589824
# _________________________________________________________________
# batch_normalization_2 (Batch multiple                  1024
# _________________________________________________________________
# custom_conv_layer_3 (CustomC multiple                  1179648
# _________________________________________________________________
# custom_pool_layer_1 (CustomP multiple                  0
# _________________________________________________________________
# batch_normalization_3 (Batch multiple                  1024
# _________________________________________________________________
# custom_conv_layer_4 (CustomC multiple                  2359296
# _________________________________________________________________
# batch_normalization_4 (Batch multiple                  2048
# _________________________________________________________________
# custom_conv_layer_5 (CustomC multiple                  4718592
# _________________________________________________________________
# custom_pool_layer_2 (CustomP multiple                  0
# _________________________________________________________________
# batch_normalization_5 (Batch multiple                  2048
# _________________________________________________________________
# custom_conv_layer_6 (CustomC multiple                  4718592
# _________________________________________________________________
# batch_normalization_6 (Batch multiple                  2048
# _________________________________________________________________
# custom_conv_layer_7 (CustomC multiple                  4718592
# _________________________________________________________________
# custom_pool_layer_3 (CustomP multiple                  0
# _________________________________________________________________
# batch_normalization_7 (Batch multiple                  2048
# _________________________________________________________________
# custom_dense_layer (CustomDe multiple                  4195328
# _________________________________________________________________
# custom_dense_layer_1 (Custom multiple                  20490
# =================================================================
# Total params: 22,662,282
# Trainable params: 11,331,658
# Non-trainable params: 11,330,624
# _________________________________________________________________
