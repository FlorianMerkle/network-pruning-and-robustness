# %% [markdown]
# done

# %%
ARCHITECTURE = 'cnn'
#EXPERIMENT_NAME = 'cnn-global-magnitude-unstruct'
ITERATIONS = 10

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow.keras import layers
from tqdm import tqdm
import matplotlib.pyplot as plt
from tqdm import tqdm
import foolbox as fb
import random
import json
from cleverhans.future.tf2.attacks import projected_gradient_descent, fast_gradient_method, carlini_wagner_l2


#tf.compat.v1.enable_eager_execution()
tf.keras.backend.clear_session()  # For easy reset of notebook state.
# Out:
# /home/florian/anaconda2/envs/master-thesis/lib/python3.8/site-packages/foolbox/attacks/brendel_bethge.py:781: NumbaDeprecationWarning: The 'numba.jitclass' decorator has moved to 'numba.experimental.jitclass' to better reflect the experimental nature of the functionality. Please update your imports to accommodate this change and see http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#change-of-jitclass-location for the time frame.
#   @jitclass(spec=[])
# /home/florian/anaconda2/envs/master-thesis/lib/python3.8/site-packages/foolbox/attacks/brendel_bethge.py:1358: NumbaDeprecationWarning: The 'numba.jitclass' decorator has moved to 'numba.experimental.jitclass' to better reflect the experimental nature of the functionality. Please update your imports to accommodate this change and see http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#change-of-jitclass-location for the time frame.
#   @jitclass(spec=spec)
# /home/florian/anaconda2/envs/master-thesis/lib/python3.8/site-packages/foolbox/attacks/brendel_bethge.py:1554: NumbaDeprecationWarning: The 'numba.jitclass' decorator has moved to 'numba.experimental.jitclass' to better reflect the experimental nature of the functionality. Please update your imports to accommodate this change and see http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#change-of-jitclass-location for the time frame.
#   @jitclass(spec=spec)
# /home/florian/anaconda2/envs/master-thesis/lib/python3.8/site-packages/foolbox/attacks/brendel_bethge.py:1706: NumbaDeprecationWarning: The 'numba.jitclass' decorator has moved to 'numba.experimental.jitclass' to better reflect the experimental nature of the functionality. Please update your imports to accommodate this change and see http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#change-of-jitclass-location for the time frame.
#   @jitclass(spec=spec)
# /home/florian/anaconda2/envs/master-thesis/lib/python3.8/site-packages/foolbox/attacks/brendel_bethge.py:1900: NumbaDeprecationWarning: The 'numba.jitclass' decorator has moved to 'numba.experimental.jitclass' to better reflect the experimental nature of the functionality. Please update your imports to accommodate this change and see http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#change-of-jitclass-location for the time frame.
#   @jitclass(spec=spec)

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    # Restrict TensorFlow to only allocate 1GB * 2 of memory on the first GPU
    try:
        tf.config.experimental.set_virtual_device_configuration(
            gpus[0],
            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=1024 * 4)])
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Virtual devices must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
run_experiment(
    structure='unstructured', 
    method='random', 
    scope='local', 
    iterations=ITERATIONS
)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 938/938 [==============================] - 3s 3ms/step - loss: 1.5958 - accuracy: 0.8881 - val_loss: 1.5117 - val_accuracy: 0.9541
# 0it [00:00, ?it/s]
# current pruning ratio is0.0, current iteration is 0
# (1.0, 61470, 61470)
# Epoch 1/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.5042 - accuracy: 0.9602 - val_loss: 1.4982 - val_accuracy: 0.9647
# Epoch 2/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4916 - accuracy: 0.9718 - val_loss: 1.4889 - val_accuracy: 0.9732
# Epoch 3/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4852 - accuracy: 0.9777 - val_loss: 1.4847 - val_accuracy: 0.9774
# Epoch 4/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4825 - accuracy: 0.9796 - val_loss: 1.4851 - val_accuracy: 0.9768
# Epoch 5/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4794 - accuracy: 0.9828 - val_loss: 1.4839 - val_accuracy: 0.9780
# Epoch 6/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.
# Epoch 12/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4913 - accuracy: 0.9739 - val_loss: 1.4903 - val_accuracy: 0.9742
# Epoch 13/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4908 - accuracy: 0.9745 - val_loss: 1.4906 - val_accuracy: 0.9737
# Epoch 14/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4900 - accuracy: 0.9755 - val_loss: 1.4897 - val_accuracy: 0.9746
# Epoch 15/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4896 - accuracy: 0.9753 - val_loss: 1.4901 - val_accuracy: 0.9746
# Epoch 16/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4891 - accuracy: 0.9758 - val_loss: 1.4892 - val_accuracy: 0.9751
# Epoch 17/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4886 - accuracy: 0.9762 - val_loss: 1.4889 - val_accuracy: 0.9755
# Epoch 18/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4882 - accuracy: 0.9767 - val_loss: 1.4884 - val_accuracy: 0.9755
# Epoch 19/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4878 - accuracy: 0.9766 - val_loss: 1.4880 - val_accuracy: 0.9756
# Epoch 20/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4873 - accuracy: 0.9775 - val_loss: 1.4892 - val_accuracy: 0.9741
# Epoch 21/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4871 - accuracy: 0.9775 - val_loss: 1.4881 - val_accuracy: 0.9757
# Epoch 22/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4868 - accuracy: 0.9780 - val_loss: 1.4872 - val_accuracy: 0.9770
# Epoch 23/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4864 - accuracy: 0.9782 - val_loss: 1.4871 - val_accuracy: 0.9765
# Epoch 24/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4862 - accuracy: 0.9784 - val_loss: 1.4872 - val_accuracy: 0.9760
# Epoch 25/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4858 - accuracy: 0.9786 - val_loss: 1.4876 - val_accuracy: 0.9759
# Epoch 26/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4856 - accuracy: 0.9790 - val_loss: 1.4874 - val_accuracy: 0.9757
# (0.01563364242720026, 961, 61470)
# 7it [17:55, 153.60s/it]
# 100%|██████████| 1/1 [17:58<00:00, 1078.53s/it]
# <class 'list'> <class 'tensorflow.python.framework.ops.EagerTensor'>

# %%
run_experiment(
    structure='structured', 
    method='random', 
    scope='local', 
    iterations=ITERATIONS
)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 938/938 [==============================] - 3s 3ms/step - loss: 1.5918 - accuracy: 0.8896 - val_loss: 1.5148 - val_accuracy: 0.9519
# 0it [00:00, ?it/s]
# current pruning ratio is0.0, current iteration is 0
# (1.0, 61470, 61470)
# Epoch 1/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.5028 - accuracy: 0.9616 - val_loss: 1.4969 - val_accuracy: 0.9665
# Epoch 2/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4910 - accuracy: 0.9723 - val_loss: 1.4877 - val_accuracy: 0.9756
# Epoch 3/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4854 - accuracy: 0.9772 - val_loss: 1.4829 - val_accuracy: 0.9793
# Epoch 4/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4816 - accuracy: 0.9808 - val_loss: 1.4825 - val_accuracy: 0.9801
# Epoch 5/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4789 - accuracy: 0.9832 - val_loss: 1.4821 - val_accuracy: 0.9800
# Epoch 6/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4773 - accuracy: 0.9847 - val_loss: 1.4791 - val_accuracy: 0.9824
# Epoch 7/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4749 - accuracy: 0.9872 - val_loss: 1.4817 - val_accuracy: 0.9795
# Epoch 8/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4744 - accuracy: 0.9874 - val_loss: 1.4764 - val_accuracy: 0.9850
# Epoch 9/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4731 - accuracy: 0.9889 - val_loss: 1.4772 - val_accuracy: 0.9845
# Epoch 10/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4725 - accuracy: 0.9893 - val_loss: 1.4766 - val_accuracy: 0.9848
# Epoch 11/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4716 - accuracy: 0.9899 - val_loss: 1.4787 - val_accuracy: 0.9836
# (1.0, 61470, 61470)
# 1it [02:16, 136.85s/it]
# <class 'list'> <class 'tensorflow.python.framework.ops.EagerTensor'>
# current pruning ratio is0.5, current iteration is 0
# (0.5, 30735, 61470)
# Epoch 1/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.
# Epoch 7/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4699 - accuracy: 0.9916 - val_loss: 1.4761 - val_accuracy: 0.9853
# (0.40317227916056614, 24783, 61470)
# 2it [07:19, 227.19s/it]
# current pruning ratio is0.75, current iteration is 1
# (0.12985196030584026, 7982, 61470)
# Epoch 1/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.5788 - accuracy: 0.8855 - val_loss: 1.5159 - val_accuracy: 0.9483
# Epoch 2/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.5103 - accuracy: 0.9536 - val_loss: 1.5026 - val_accuracy: 0.9604
# Epoch 3/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.5021 - accuracy: 0.9613 - val_loss: 1.4993 - val_accuracy: 0.9637
# Epoch 4/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4976 - accuracy: 0.9653 - val_loss: 1.4966 - val_accuracy: 0.9659
# Epoch 5/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4948 - accuracy: 0.9679 - val_loss: 1.4935 - val_accuracy: 0.9697
# Epoch 6/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4925 - accuracy: 0.9699 - val_loss: 1.4926 - val_accuracy: 0.9693
# Epoch 7/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4903 - accuracy: 0.9722 - val_loss: 1.4902 - val_accuracy: 0.9721
# Epoch 8/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4890 - accuracy: 0.9734 - val_loss: 1.4907 - val_accuracy: 0.9709
# Epoch 9/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4879 - accuracy: 0.9747 - val_loss: 1.4891 - val_accuracy: 0.9734
# Epoch 10/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4871 - accuracy: 0.9751 - val_loss: 1.4892 - val_accuracy: 0.9725
# Epoch 11/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4859 - accuracy: 0.9763 - val_loss: 1.4877 - val_accuracy: 0.9741
# Epoch 12/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4851 - accuracy: 0.9769 - val_loss: 1.4859 - val_accuracy: 0.9763
# Epoch 13/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4845 - accuracy: 0.9775 - val_loss: 1.4858 - val_accuracy: 0.9765
# Epoch 14/500
# 938/938 [==============================] - 2s 2ms/step - loss: 1.4836 - accuracy: 0.9783 - val_loss: 1.4858 - val_accuracy: 0.9762
# Epoch 15/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4831 - accuracy: 0.9791 - val_loss: 1.4842 - val_accuracy: 0.9777
# Epoch 16/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4826 - accuracy: 0.9793 - val_loss: 1.4847 - val_accuracy: 0.9769
# Epoch 17/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4818 - accuracy: 0.9801 - val_loss: 1.4846 - val_accuracy: 0.9772
# Epoch 18/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4811 - accuracy: 0.9809 - val_loss: 1.4848 - val_accuracy: 0.9767
# (0.12985196030584026, 7982, 61470)
# 3it [11:10, 228.40s/it]
# current pruning ratio is0.875, current iteration is 1
# (0.017650886611355134, 1085, 61470)
# Epoch 1/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3028 - accuracy: 0.1119 - val_loss: 2.3013 - val_accuracy: 0.1135
# Epoch 2/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3016 - accuracy: 0.1120 - val_loss: 2.3012 - val_accuracy: 0.1135
# Epoch 3/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3015 - accuracy: 0.1121 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 4/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3014 - accuracy: 0.1124 - val_loss: 2.3012 - val_accuracy: 0.1135
# Epoch 5/500
# 938/938 [==============================] - 2s 2ms/step - loss: 2.3014 - accuracy: 0.1116 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 6/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3014 - accuracy: 0.1124 - val_loss: 2.3012 - val_accuracy: 0.1135
# Epoch 7/500
# 938/938 [==============================] - 2s 2ms/step - loss: 2.3015 - accuracy: 0.1122 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 8/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1120 - val_loss: 2.3014 - val_accuracy: 0.1028
# (0.017650886611355134, 1085, 61470)
# 4it [12:46, 188.85s/it]
# current pruning ratio is0.9375, current iteration is 1
# (0.009028794533918985, 555, 61470)
# Epoch 1/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3015 - accuracy: 0.1119 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 2/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 3/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3014 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 4/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# (0.009028794533918985, 555, 61470)
# 5it [14:15, 158.83s/it]
# current pruning ratio is0.96875, current iteration is 1
# (0.004717748495200911, 290, 61470)
# Epoch 1/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 2/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 3/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 4/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 5/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 6/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 7/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# (0.004717748495200911, 290, 61470)
# 6it [15:49, 139.46s/it]
# current pruning ratio is0.984375, current iteration is 1
# (0.002440214738897023, 150, 61470)
# Epoch 1/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3014 - accuracy: 0.1110 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 2/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 3/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 4/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# (0.002440214738897023, 150, 61470)
# 7it [17:16, 148.13s/it]
#  20%|██        | 2/10 [34:02<2:15:11, 1013.88s/it]
# 938/938 [==============================] - 2s 3ms/step - loss: 1.
- val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 6/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3014 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 7/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3014 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 8/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# (0.009028794533918985, 555, 61470)
# 5it [14:30, 155.92s/it]
# current pruning ratio is0.96875, current iteration is 2
# (0.004717748495200911, 290, 61470)
# Epoch 1/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3015 - accuracy: 0.1118 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 2/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 3/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 4/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 5/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 6/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 7/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# (0.004717748495200911, 290, 61470)
# 6it [16:03, 137.11s/it]
# current pruning ratio is0.984375, current iteration is 2
# (0.002440214738897023, 150, 61470)
# Epoch 1/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 2/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 3/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 4/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 5/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 6/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 7/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 8/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# (0.002440214738897023, 150, 61470)
# 7it [17:40, 151.49s/it]
#  30%|███       | 3/10 [51:45<2:00:00, 1028.70s/it]
# 938/938 [==============================] - 3s 3ms/step - loss: 1.5881 - accuracy: 0.8970 - val_loss: 1.5123 - val_accuracy: 0.9535
# 0it [00:00, ?it/s]
# current pruning ratio is0.0, current iteration is 3
# (1.0, 61470, 61470)
# Epoch 1/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.5020 - accuracy: 0.9623 - val_loss: 1.4961 - val_accuracy: 0.9666
# Epoch 2/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4919 - accuracy: 0.9710 - val_loss: 1.4877 - val_accuracy: 0.9750
# Epoch 3/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4856 - accuracy: 0.9769 - val_loss: 1.4880 - val_accuracy: 0.9743
# Epoch 4/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4818 - accuracy: 0.9805 - val_loss: 1.4871 - val_accuracy: 0.9749
# Epoch 5/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4790 - accuracy: 0.9836 - val_loss: 1.4810 - val_accuracy: 0.9815
# Epoch 6/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4777 - accuracy: 0.9841 - val_loss: 1.4813 - val_accuracy: 0.9801
# Epoch 7/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4763 - accuracy: 0.9858 - val_loss: 1.4784 - val_accuracy: 0.9832
# Epoch 8/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4748 - accuracy: 0.9870 - val_loss: 1.4807 - val_accuracy: 0.9811
# Epoch 9/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4737 - accuracy: 0.9880 - val_loss: 1.4765 - val_accuracy: 0.9856
# Epoch 10/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4730 - accuracy: 0.9884 - val_loss: 1.4785 - val_accuracy: 0.9835
# Epoch 11/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4721 - accuracy: 0.9894 - val_loss: 1.4771 - val_accuracy: 0.9846
# Epoch 12/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4713 - accuracy: 0.9904 - val_loss: 1.4756 - val_accuracy: 0.9861
# Epoch 13/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4705 - accuracy: 0.9912 - val_loss: 1.4783 - val_accuracy: 0.9830
# Epoch 14/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4710 - accuracy: 0.9906 - val_loss: 1.4754 - val_accuracy: 0.9858
# Epoch 15/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4697 - accuracy: 0.9920 - val_loss: 1.4759 - val_accuracy: 0.9853
# Epoch 16/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4697 - accuracy: 0.9919 - val_loss: 1.4753 - val_accuracy: 0.9862
# Epoch 17/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4693 - accuracy: 0.9921 - val_loss: 1.4744 - val_accuracy: 0.9875
# Epoch 18/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4682 - accuracy: 0.9935 - val_loss: 1.4742 - val_accuracy: 0.9871
# Epoch 19/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4689 - accuracy: 0.9927 - val_loss: 1.4766 - val_accuracy: 0.9848
# Epoch 20/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4683 - accuracy: 0.9931 - val_loss: 1.4752 - val_accuracy: 0.9861
# Epoch 21/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4678 - accuracy: 0.9938 - val_loss: 1.4754 - val_accuracy: 0.9862
# (1.0, 61470, 61470)
# 1it [03:38, 218.35s/it]
# current pruning ratio is0.5, current iteration is 3
# (0.40551488530990726, 24927, 61470)
# Epoch 1/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4847 - accuracy: 0.9770 - val_loss: 1.4805 - val_accuracy: 0.9813
# Epoch 2/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4749 - accuracy: 0.9869 - val_loss: 1.4780 - val_accuracy: 0.9842
# Epoch 3/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4724 - accuracy: 0.9894 - val_loss: 1.4761 - val_accuracy: 0.9853
# Epoch 4/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.
 61470)
# Epoch 1/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3030 - accuracy: 0.1122 - val_loss: 2.3021 - val_accuracy: 0.1028
# Epoch 2/500
# 938/938 [==============================] - 2s 2ms/step - loss: 2.3015 - accuracy: 0.1114 - val_loss: 2.3013 - val_accuracy: 0.1135
# Epoch 3/500
# 938/938 [==============================] - 2s 2ms/step - loss: 2.3015 - accuracy: 0.1114 - val_loss: 2.3012 - val_accuracy: 0.1135
# Epoch 4/500
# 938/938 [==============================] - 2s 2ms/step - loss: 2.3015 - accuracy: 0.1111 - val_loss: 2.3012 - val_accuracy: 0.1135
# Epoch 5/500
# 938/938 [==============================] - 2s 2ms/step - loss: 2.3015 - accuracy: 0.1118 - val_loss: 2.3012 - val_accuracy: 0.1028
# Epoch 6/500
# 938/938 [==============================] - 2s 2ms/step - loss: 2.3015 - accuracy: 0.1117 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 7/500
# 938/938 [==============================] - 2s 2ms/step - loss: 2.3015 - accuracy: 0.1117 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 8/500
# 938/938 [==============================] - 2s 2ms/step - loss: 2.3014 - accuracy: 0.1111 - val_loss: 2.3013 - val_accuracy: 0.1135
# Epoch 9/500
# 938/938 [==============================] - 2s 2ms/step - loss: 2.3015 - accuracy: 0.1116 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 10/500
# 938/938 [==============================] - 2s 2ms/step - loss: 2.3015 - accuracy: 0.1121 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 11/500
# 938/938 [==============================] - 2s 2ms/step - loss: 2.3014 - accuracy: 0.1116 - val_loss: 2.3013 - val_accuracy: 0.1135
# Epoch 12/500
# 938/938 [==============================] - 2s 2ms/step - loss: 2.3015 - accuracy: 0.1119 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 13/500
# 938/938 [==============================] - 2s 2ms/step - loss: 2.3014 - accuracy: 0.1115 - val_loss: 2.3014 - val_accuracy: 0.1135
# Epoch 14/500
# 938/938 [==============================] - 2s 2ms/step - loss: 2.3014 - accuracy: 0.1124 - val_loss: 2.3013 - val_accuracy: 0.1135
# Epoch 15/500
# 938/938 [==============================] - 2s 2ms/step - loss: 2.3015 - accuracy: 0.1122 - val_loss: 2.3012 - val_accuracy: 0.1135
# (0.017650886611355134, 1085, 61470)
# 4it [12:49, 188.41s/it]
# current pruning ratio is0.9375, current iteration is 3
# (0.009028794533918985, 555, 61470)
# Epoch 1/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3017 - accuracy: 0.1107 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 2/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3014 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 3/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1121 - val_loss: 2.3013 - val_accuracy: 0.1135
# Epoch 4/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1117 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 5/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 6/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1122 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 7/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 8/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 9/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 10/500
# ...
# Epoch 7/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3015 - accuracy: 0.1114 - val_loss: 2.3013 - val_accuracy: 0.1135
# Epoch 8/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3014 - accuracy: 0.1122 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 9/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3015 - accuracy: 0.1119 - val_loss: 2.3014 - val_accuracy: 0.1135
# Epoch 10/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3014 - accuracy: 0.1112 - val_loss: 2.3009 - val_accuracy: 0.1135
# Epoch 11/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3014 - accuracy: 0.1120 - val_loss: 2.3012 - val_accuracy: 0.1135
# Epoch 12/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3014 - accuracy: 0.1119 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 13/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3014 - accuracy: 0.1122 - val_loss: 2.3014 - val_accuracy: 0.1135
# (0.017650886611355134, 1085, 61470)
# 4it [12:41, 187.15s/it]
# current pruning ratio is0.9375, current iteration is 8
# (0.009028794533918985, 555, 61470)
# Epoch 1/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3016 - accuracy: 0.1118 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 2/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 3/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 4/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1121 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 5/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 6/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 7/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1116 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 8/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 9/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 10/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# (0.009028794533918985, 555, 61470)
# 5it [14:23, 161.69s/it]
# current pruning ratio is0.96875, current iteration is 8
# (0.004717748495200911, 290, 61470)
# Epoch 1/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 2/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 3/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 4/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 5/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# (0.004717748495200911, 290, 61470)
# 6it [15:55, 140.86s/it]
# current pruning ratio is0.984375, current iteration is 8
# (0.002440214738897023, 150, 61470)
# Epoch 1/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 2/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 3/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 4/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 5/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 6/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 7/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# (0.002440214738897023, 150, 61470)
# 7it [17:29, 149.86s/it]
#  90%|█████████ | 9/10 [2:37:28<17:31, 1051.34s/it]
# 938/938 [==============================] - 2s 3ms/step - loss: 1.5963 - accuracy: 0.8849 - val_loss: 1.5123 - val_accuracy: 0.9536
# 0it [00:00, ?it/s]
# current pruning ratio is0.0, current iteration is 9
# (1.0, 61470, 61470)
# Epoch 1/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.5010 - accuracy: 0.9637 - val_loss: 1.4918 - val_accuracy: 0.9710
# Epoch 2/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4891 - accuracy: 0.9742 - val_loss: 1.4845 - val_accuracy: 0.9788
# Epoch 3/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4838 - accuracy: 0.9789 - val_loss: 1.4848 - val_accuracy: 0.9775
# Epoch 4/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4802 - accuracy: 0.9820 - val_loss: 1.4812 - val_accuracy: 0.9806
# Epoch 5/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.
500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4951 - accuracy: 0.9672 - val_loss: 1.4955 - val_accuracy: 0.9663
# Epoch 8/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4932 - accuracy: 0.9697 - val_loss: 1.4959 - val_accuracy: 0.9667
# Epoch 9/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4922 - accuracy: 0.9700 - val_loss: 1.4941 - val_accuracy: 0.9681
# Epoch 10/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4909 - accuracy: 0.9715 - val_loss: 1.4920 - val_accuracy: 0.9702
# Epoch 11/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4901 - accuracy: 0.9723 - val_loss: 1.4927 - val_accuracy: 0.9689
# Epoch 12/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4890 - accuracy: 0.9737 - val_loss: 1.4915 - val_accuracy: 0.9710
# Epoch 13/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4880 - accuracy: 0.9745 - val_loss: 1.4897 - val_accuracy: 0.9721
# Epoch 14/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4870 - accuracy: 0.9751 - val_loss: 1.4887 - val_accuracy: 0.9728
# Epoch 15/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4862 - accuracy: 0.9761 - val_loss: 1.4873 - val_accuracy: 0.9742
# Epoch 16/500
# 938/938 [==============================] - 2s 2ms/step - loss: 1.4856 - accuracy: 0.9766 - val_loss: 1.4892 - val_accuracy: 0.9719
# Epoch 17/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4851 - accuracy: 0.9775 - val_loss: 1.4883 - val_accuracy: 0.9736
# Epoch 18/500
# 938/938 [==============================] - 2s 2ms/step - loss: 1.4845 - accuracy: 0.9777 - val_loss: 1.4869 - val_accuracy: 0.9758
# Epoch 19/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4840 - accuracy: 0.9781 - val_loss: 1.4864 - val_accuracy: 0.9750
# Epoch 20/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4839 - accuracy: 0.9783 - val_loss: 1.4868 - val_accuracy: 0.9750
# Epoch 21/500
# 938/938 [==============================] - 2s 3ms/step - loss: 1.4833 - accuracy: 0.9789 - val_loss: 1.4870 - val_accuracy: 0.9749
# Epoch 22/500
# 938/938 [==============================] - 2s 2ms/step - loss: 1.4825 - accuracy: 0.9796 - val_loss: 1.4867 - val_accuracy: 0.9750
# (0.1280950056938344, 7874, 61470)
# 3it [11:06, 222.78s/it]
# current pruning ratio is0.875, current iteration is 9
# (0.017650886611355134, 1085, 61470)
# Epoch 1/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3027 - accuracy: 0.1116 - val_loss: 2.3014 - val_accuracy: 0.1135
# Epoch 2/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3016 - accuracy: 0.1115 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 3/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3015 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 4/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3014 - accuracy: 0.1114 - val_loss: 2.3012 - val_accuracy: 0.1135
# Epoch 5/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3014 - accuracy: 0.1122 - val_loss: 2.3012 - val_accuracy: 0.1135
# (0.017650886611355134, 1085, 61470)
# 4it [12:34, 182.59s/it]
# current pruning ratio is0.9375, current iteration is 9
# (0.009028794533918985, 555, 61470)
# Epoch 1/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3016 - accuracy: 0.1104 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 2/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3012 - val_accuracy: 0.1135
# Epoch 3/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1121 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 4/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# (0.009028794533918985, 555, 61470)
# 5it [14:02, 154.23s/it]
# current pruning ratio is0.96875, current iteration is 9
# (0.004717748495200911, 290, 61470)
# Epoch 1/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3014 - accuracy: 0.1122 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 2/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 3/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 4/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 5/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3011 - val_accuracy: 0.1135
# Epoch 6/500
# 938/938 [==============================] - 3s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# (0.004717748495200911, 290, 61470)
# 6it [15:35, 135.79s/it]
# current pruning ratio is0.984375, current iteration is 9
# (0.002440214738897023, 150, 61470)
# Epoch 1/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3013 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 2/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 3/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# Epoch 4/500
# 938/938 [==============================] - 2s 3ms/step - loss: 2.3012 - accuracy: 0.1124 - val_loss: 2.3010 - val_accuracy: 0.1135
# (0.002440214738897023, 150, 61470)
# 7it [17:02, 146.03s/it]
# 100%|██████████| 10/10 [2:54:33<00:00, 1047.36s/it]

# %% [markdown]
# # Prune, Train Attack Pipeline

# %%
def run_experiment(structure='unstructured', method='random', scope='global', iterations=10):
    
    experiment_name = f'{ARCHITECTURE}-{method}-{scope}-{structure}'
    pgd_success_rates = []
    cw_success_rates = []
    bb0_success_rates = []
    all_accuracies = []

    #compression_rates = [1, 2, 4, 64]
    compression_rates = [tf.math.pow(2, x).numpy() for x in range(7)]
    pruning_ratios = [1-1/x for x in compression_rates]

    for j in tqdm(range(iterations)):
        accuracies = []
        pgd_success_rate = []
        cw_success_rate = []
        bb0_success_rate = []
        try: 
            del model
        except:
            ;
        tf.compat.v1.reset_default_graph()
        tf.keras.backend.clear_session()
        
        model = initialize_base_model(j, experiment_name=experiment_name, save_weights=True)
        for index, pruning_ratio in tqdm(enumerate(pruning_ratios)):

            #model.load_weights(f'./saved-weights/{experiment_name}-{j}')
            #print(f'./saved-weights/{experiment_name}-{j}')

            #for i in range(index + 1):
                print(f'current pruning ratio is{pruning_ratio}, current iteration is {j}')
                #if i != index:

                if  method=='random' and scope=='global' and structure=='unstructured':
                    model.prune_random_global_unstruct(pruning_ratio)
                elif  method=='random' and scope=='global' and structure=='structured':
                    model.prune_random_global_struct(pruning_ratio)
                elif  method=='random' and scope=='local' and structure=='unstructured':
                    model.prune_random_local_unstruct(pruning_ratio)
                elif  method=='random' and scope=='local' and structure=='structured':
                    model.prune_random_local_struct(pruning_ratio)
                elif  method=='magnitude' and scope=='global' and structure=='unstructured':
                    model.prune_magnitude_global_unstruct(pruning_ratio)
                elif  method=='magnitude' and scope=='global' and structure=='structured':
                    model.prune_magnitude_global_struct(pruning_ratio)
                elif  method=='magnitude' and scope=='local' and structure=='unstructured':
                    model.prune_magnitude_local_unstruct(pruning_ratio)
                elif  method=='magnitude' and scope=='local' and structure=='structured':
                    model.prune_magnitude_local_struct(pruning_ratio)
                else:
                    raise ValueError("pruning method invalid")

                print(get_zeros_ratio(model.get_weights()))
                model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True) ,
                              metrics=['accuracy'],
                              experimental_run_tf_function=False
                             )
                model = train_model(model, to_convergence=True)
                print(get_zeros_ratio(model.get_weights()))
                accuracies.append(model.evaluate(x_test, y_test, verbose=0))
                pgd_success_rate.append(pgd_attack(model))
                cw_success_rate.append(cw2_attack(model))
                bb0_success_rate.append(bb0_attack(model))
        all_accuracies.append(accuracies)
        pgd_success_rates.append(pgd_success_rate)
        cw_success_rates.append(cw_success_rate)
        bb0_success_rates.append(bb0_success_rate)
    #write to csv and json
    with open(f'saved-results/{experiment_name}-accuracies.json', 'w') as f:
        json.dump(all_accuracies, f)

    with open(f'saved-results/{experiment_name}-pgd-success.json', 'w') as f:
        json.dump(pgd_success_rates, f)
        
    with open(f'saved-results/{experiment_name}-cw2-success.json', 'w') as f:
        json.dump(cw_success_rates, f)
        
    with open(f'saved-results/{experiment_name}-bb0-success.json', 'w') as f:
        json.dump(bb0_success_rates, f)

# %% [markdown]
# # Prune, Train Attack Pipeline

# %%
for idx,x in enumerate(all_accuracies):
    for idy,y in enumerate(x):
        all_accuracies[idx][idy] = [float(y[0]), float(y[1])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-71e5815d8ce2> in <module>
# ----> 1 for idx,x in enumerate(all_accuracies):
#       2     for idy,y in enumerate(x):
#       3         all_accuracies[idx][idy] = [float(y[0]), float(y[1])]
#
# NameError: name 'all_accuracies' is not defined

# %% [markdown]
# # Helper Functions

# %%
def get_zeros_ratio(weights):
    layers_to_examine = [0,3,6,9,12]
    all_weights = np.array([])
    for x in layers_to_examine:

        all_weights = np.append(all_weights, weights[x].flatten())
    return np.count_nonzero(all_weights)/len(all_weights), np.count_nonzero(all_weights), len(all_weights)

def initialize_base_model(index, experiment_name, save_weights=False):

    model = CustomConvModel()

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True) ,
                  metrics=['accuracy'],
                  experimental_run_tf_function=False
                 )

    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)
    model.fit(x=x_train,
              y=y_train,
              batch_size=64,
              epochs=1,
              callbacks=[callback],
              validation_data=(x_test, y_test),
             )
    if save_weights == True:
        model.save_weights(f'./saved-weights/{experiment_name}-{index}')
    return model



def train_model(model, to_convergence=True):
    if to_convergence == True:
        callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)
        model.fit(
            x=x_train,
            y=y_train,
            batch_size=64,
            epochs=500,
            callbacks=[callback],
            validation_data=(x_test, y_test),
            )
    if to_convergence == False:
        callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)
        model.fit(
            x=x_train,
            y=y_train,
            batch_size=64,
            epochs=100,
            callbacks=[callback],
            validation_data=(x_test, y_test),
            )
    return model

def pgd_attack(model_to_attack):
    fmodel = fb.models.TensorFlowModel(model_to_attack, bounds=(0,1))
    attack = fb.attacks.LinfProjectedGradientDescentAttack()
    adversarials = attack(
        fmodel,
        x_to_attack,
        y_to_attack,
        epsilons=[8/255]
    )
    return np.count_nonzero(adversarials[2])/len(y_to_attack)

def cw2_attack(model_to_attack, eps=[.5]):
    fmodel = fb.models.TensorFlowModel(model_to_attack, bounds=(0,1))
    attack = fb.attacks.L2CarliniWagnerAttack()
    adversarials, _, success = attack(
        fmodel,
        x_to_attack,
        y_to_attack,
        epsilons=eps
    )
    return np.count_nonzero(success)/len(y_to_attack)

def bb0_attack(model_to_attack):
    fmodel = fb.models.TensorFlowModel(model_to_attack, bounds=(0,1))
    try:
        attack = fb.attacks.L0BrendelBethgeAttack(binary_search_steps=100, lr=1e7)
        adversarials, _, success = attack(
            fmodel,
            x_to_attack,
            y_to_attack,
            epsilons=[None]
        )
    except:
        attack = fb.attacks.L0BrendelBethgeAttack(binary_search_steps=100, lr=1e7, init_attack=fb.attacks.LinearSearchBlendedUniformNoiseAttack(steps=20000))
        adversarials, _, success = attack(
            fmodel,
            x_to_attack,
            y_to_attack,
            epsilons=[None]
        )
    dists = [np.count_nonzero(x_to_attack[i]-adversarials[0][i]) for i in range(len(x_to_attack))]
    return dists, ([x.numpy().tolist() for x in adversarials], success.numpy().tolist())


def prune_conv_layers(pruning_ratio):
    layer_to_prune = [0, 3]
    pruned_weights = model.get_weights()
    
    for layer in layer_to_prune:
        converted_weights = convert_from_hwio_to_iohw(model.get_weights()[layer])
        converted_mask = convert_from_hwio_to_iohw(model.get_weights()[layer + 2]).numpy()
        for input_index, input_layer in enumerate(converted_weights):

            for kernel_index, kernel in enumerate(input_layer):
                dims = kernel.shape
                flat_weights = kernel.numpy().flatten()
                flat_masks = converted_mask[input_index][kernel_index].flatten()
                flat_weights_df = pd.DataFrame(flat_weights)
                flat_mask_df = pd.DataFrame(flat_masks)
                no_of_weights_to_prune = int(len(flat_weights)*pruning_ratio)
                #print(no_of_weights_to_prune)
                indices_to_delete = flat_weights_df.abs().values.argsort(0)[:no_of_weights_to_prune]
                for idx_to_delete in indices_to_delete:
                    flat_masks[idx_to_delete] = 0

                converted_mask[input_index][kernel_index] = flat_masks.reshape(dims)
        back_converted_mask = convert_from_iohw_to_hwio(converted_mask)
        pruned_weights[layer+2] = back_converted_mask
    
    return pruned_weights

def convert_from_hwio_to_iohw(weights_nchw):
    return tf.transpose(weights_nchw, [2, 3, 0, 1])



def convert_from_iohw_to_hwio(weights_nhwc):
    return tf.transpose(weights_nhwc, [2, 3, 0, 1])


def get_average_accuracies(all_accuracies):
    acc_per_pruning_rate=[]
    for i in range(len(all_accuracies)):
        for j in range(len(all_accuracies[i])):

            try:
                acc_per_pruning_rate[j].append(all_accuracies[i][j][1])
            except:
                acc_per_pruning_rate.append([])
                acc_per_pruning_rate[j].append(all_accuracies[i][j][1])
    avg_acc_per_pruning_rate = [sum(x)/len(x) for x in acc_per_pruning_rate]; avg_acc_per_pruning_rate
    return avg_acc_per_pruning_rate

def get_average_success_rates(all_success_rates):
    success_per_pruning_rate=[]
    for i in range(len(all_success_rates)):
        for j in range(len(all_success_rates[i])):

            try:
                success_per_pruning_rate[j].append(all_success_rates[i][j])
            except:
                success_per_pruning_rate.append([])
                success_per_pruning_rate[j].append(all_success_rates[i][j])
    avg_success_per_pruning_rate = [sum(x)/len(x) for x in success_per_pruning_rate];avg_success_per_pruning_rate
    return avg_success_per_pruning_rate

# %% [markdown]
# # Load Data

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train.reshape(60000, 784).astype('float32') / 255
x_test = x_test.reshape(10000, 784).astype('float32') / 255

x_to_attack = tf.convert_to_tensor(x_train[:10].reshape(10,28*28))
y_to_attack = tf.convert_to_tensor([y_train[:10]])[0];

# %% [markdown]
# # Define Model

# %%
shapes = {
    # 5x5 conv, 1 input, 6 outputs
    'conv_1': (5, 5, 1, 6),
    # 5x5 conv, 6 inputs, 16 outputs
    'conv_2': (5, 5, 6, 16),
    #5x5 conv as in paper, 16 inputs, 120 outputs
    'conv_3': (1, 1, 16, 120),
    # fully connected, 5*5*16 inputs, 120 outputs
    'dense_1': (5*5*16, 120),
    # fully connected, 120 inputs, 84 outputs
    'dense_2': (120, 84),
    # 84 inputs, 10 outputs (class prediction)
    'dense_3': (84, 10),
}
bias_shapes = {
    #output depth
    'conv_1': (6),
    'conv_2': (16),
    'dense_1': (120),
    'dense_2': (84),
    'dense_3': (10),
}

#conv2D with bias and relu activation

class CustomConvLayer(layers.Layer):

    def __init__(self, weights, mask, biases, strides, padding='SAME'):
        
        super(CustomConvLayer, self).__init__()
        self.w = weights
        self.m = mask
        self.b = biases
        self.s = strides
        self.p = padding

        
    def call(self, inputs):
        x = tf.nn.conv2d(inputs, tf.multiply(self.w, self.m), strides=[1, self.s, self.s, 1], padding=self.p,)# data_format='NCHW')
        x = tf.nn.bias_add(x, self.b,)# 'NC...')
        return tf.nn.tanh(x)
        

#Average Pooling Layer
class CustomPoolLayer(layers.Layer):
    
    def __init__(self, k=2, padding='valid'):#padding='VALID'):
        super(CustomPoolLayer, self).__init__()
        self.k = k
        self.p = padding
    
    def call(self, inputs):
#        return tf.keras.layers.AveragePooling2D(pool_size=(self.k, self.k), strides=None, padding=self.p, data_format='channels_first')(inputs)
        return tf.nn.avg_pool2d(inputs, ksize=[1, self.k, self.k,1], strides=[1, self.k, self.k, 1], padding=self.p,)# data_format='NCHW')
    

        
class CustomConvLayer(layers.Layer):

    def __init__(self, shape, bias, strides, padding='SAME'):
        
        super(CustomConvLayer, self).__init__()
        self.w = self.add_weight(
            shape=shape,
            initializer='random_normal',
            trainable=True,
            name='w'
        )
        self.m = self.add_weight(
            shape=shape,
            initializer='ones',
            trainable=False,
            name='m'
        )
        self.b = self.add_weight(
            shape = (shape[-1]),
            initializer = 'zeros',
            trainable = True,
            name='b'
        )
        self.s = strides
        self.p = padding

        
    def call(self, inputs):
        x = tf.nn.conv2d(inputs, tf.multiply(self.w, self.m), strides=[1, self.s, self.s, 1], padding=self.p,)# data_format='NCHW')
        x = tf.nn.bias_add(x, self.b,)# 'NC...')
        return tf.nn.tanh(x)

#Dense Layer with Bias
class CustomDenseLayer(layers.Layer):
    def __init__(self, shape, bias, activation = 'tanh'):
        super(CustomDenseLayer, self).__init__()
        self.w = self.add_weight(
            shape = shape,
            initializer='random_normal',
            trainable = True,
            name='w'
        )
        self.m = self.add_weight(
            shape = shape,
            initializer='ones',
            trainable = False,
            name='m'
        )
        self.b = self.add_weight(
            shape = (shape[-1]),
            initializer = 'zeros',
            trainable = True,
            name='b'
        )
        self.a = activation
        
        
    def call(self, inputs):
        x = tf.matmul(inputs, tf.multiply(self.w, self.m))
        x = tf.nn.bias_add(x, self.b)
        if self.a == 'tanh':
            return tf.nn.tanh(x)
        if self.a == 'softmax':
            return tf.nn.softmax(x)
        
        
class CustomConvModel(tf.keras.Model):
    def __init__(self):
        super(CustomConvModel, self).__init__()
        self.conv1 = CustomConvLayer(shapes['conv_1'], True, 1, 'SAME')#'VALID')
        self.maxpool1 = CustomPoolLayer(k=2, padding='SAME')
        self.conv2 = CustomConvLayer(shapes['conv_2'], True, 1, 'VALID')
        self.maxpool2 = CustomPoolLayer(k=2, padding='VALID')

        self.dense1 = CustomDenseLayer(shapes['dense_1'], True, 'tanh')
        self.dense2 = CustomDenseLayer(shapes['dense_2'], True, 'tanh')
        self.dense3 = CustomDenseLayer(shapes['dense_3'], True, 'softmax')
        
    def call(self, inputs):
        x = tf.reshape(inputs, shape=[-1,28, 28, 1])
        x = self.conv1(x)
        x = self.maxpool1(x)
        x = self.conv2(x)
        x = self.maxpool2(x)
        x = layers.Flatten()(x)
        x = self.dense1(x)
        x = self.dense2(x)
        x =  self.dense3(x)
        return x
    
    def prune_random_local_unstruct(self, ratio):
        def prune_conv_layers_locally(self, ratio):
            conv_layer_to_prune = [0, 3]
            weights = self.get_weights()
            for layer in conv_layer_to_prune:
                converted_weights = convert_from_hwio_to_iohw(weights[layer]).numpy()
                converted_mask = convert_from_hwio_to_iohw(weights[layer + 2]).numpy()
                for input_index, input_layer in enumerate(converted_weights):
                    for kernel_index, kernel in enumerate(input_layer):
                        shape = kernel.shape
                        flat_weights = kernel.flatten()
                        flat_masks = converted_mask[input_index][kernel_index].flatten()
                        
                        no_of_weighs_to_prune = ratio * len(flat_weights)
                        # find unpruned weights
                        non_zero_weights = np.nonzero(flat_masks)[0]
                        # calculate the amount of weights to be pruned this round
                        no_of_weights_to_prune_left = int(no_of_weighs_to_prune - (len(flat_weights) - len(non_zero_weights)) )
                        # shuffle all non-zero weights
                        random.shuffle(non_zero_weights)
                        # and take the indices of the first x weights where x is the number of weights to be pruned this round
                        indices_to_delete = non_zero_weights[:no_of_weights_to_prune_left]
                        
                        for idx_to_delete in indices_to_delete:
                            flat_masks[idx_to_delete] = 0
                            flat_weights[idx_to_delete] = 0
                        converted_mask[input_index][kernel_index] = flat_masks.reshape(shape)
                        converted_weights[input_index][kernel_index] = flat_weights.reshape(shape)
                back_converted_mask = convert_from_iohw_to_hwio(converted_mask)
                back_converted_weights = convert_from_iohw_to_hwio(converted_weights)
                weights[layer] = back_converted_weights
                weights[layer+2] = back_converted_mask
            self.set_weights(weights)
            return True
        
        def prune_dense_layers_locally(self, ratio):
            dense_layer_to_prune = [6, 9, 12]
            weights = self.get_weights()
            for index, weight in enumerate(weights):
                if index in dense_layer_to_prune:
                    shape = weight.shape
                    flat_weights = weight.flatten()
                    flat_mask = weights[index+2].flatten()
                    no_of_weighs_to_prune = ratio * len(flat_weights)
                    # find unpruned weights
                    non_zero_weights = np.nonzero(flat_mask)[0]
                    # calculate the amount of weights to be pruned this round
                    no_of_weights_to_prune_left = int(no_of_weighs_to_prune - (len(flat_weights) - len(non_zero_weights)) )
                    # shuffle all non-zero weights
                    random.shuffle(non_zero_weights)
                    # and take the indices of the first x weights where x is the number of weights to be pruned this round
                    indices_to_delete = non_zero_weights[:no_of_weights_to_prune_left]
                    for idx_to_delete in indices_to_delete:
                        flat_mask[idx_to_delete] = 0
                        flat_weights[idx_to_delete] = 0

                    mask_reshaped = flat_mask.reshape(shape)
                    weights_reshaped = flat_weights.reshape(shape)
                    weights[index+2] = mask_reshaped
                    weights[index] = weights_reshaped
            self.set_weights(weights)
            return True
        prune_conv_layers_locally(self, ratio)
        prune_dense_layers_locally(self,ratio)
    
    def prune_magnitude_global_unstruct(self, ratio):
        #flat out all weights:
        conv_layer_to_prune = [0, 3]
        dense_layer_to_prune = [6, 9, 12]
        weights = self.get_weights()
        flat_weights = []
        flat_mask = []
        for x in conv_layer_to_prune + dense_layer_to_prune:
            flat_weights = np.append(flat_weights, weights[x])
            flat_mask = np.append(flat_mask, weights[x+2])
            
        no_of_weights_to_prune = int(len(flat_weights)*ratio)
        indices_to_delete = np.abs(flat_weights).argsort(0)[:no_of_weights_to_prune]
        
        for idx_to_delete in indices_to_delete:
            flat_mask[idx_to_delete] = 0
            flat_weights[idx_to_delete] = 0
        z = 0
        for x in conv_layer_to_prune + dense_layer_to_prune:
            weights[x] = flat_weights[z:z + np.prod(weights[x].shape)].reshape(weights[x].shape)
            weights[x + 2] = flat_mask[z:z + np.prod(weights[x].shape)].reshape(weights[x].shape)
            z = z + np.prod(weights[x].shape)            
        self.set_weights(weights)
        
        
            
        
        
    
    def prune_magnitude_local_unstruct(self, ratio):
        def prune_conv_layers_locally(self, ratio):
            conv_layer_to_prune = [0, 3]
            #print('inside conv prune func',get_zeros_ratio(self.get_weights()))
            weights = self.get_weights()
            
            for layer in conv_layer_to_prune:
                converted_weights = convert_from_hwio_to_iohw(weights[layer]).numpy()
                converted_mask = convert_from_hwio_to_iohw(weights[layer + 2]).numpy()
                for input_index, input_layer in enumerate(converted_weights):
                    for kernel_index, kernel in enumerate(input_layer):
                        shape = kernel.shape
                        flat_weights = kernel.flatten()
                        flat_masks = converted_mask[input_index][kernel_index].flatten()
                        #flat_weights_df = pd.DataFrame(flat_weights)
                        #flat_mask_df = pd.DataFrame(flat_masks)
                        no_of_weights_to_prune = int(len(flat_weights)*ratio)
                        #print(no_of_weights_to_prune)
                        #indices_to_delete = flat_weights_df.abs().values.argsort(0)[:no_of_weights_to_prune]
                        indices_to_delete = np.abs(flat_weights).argsort(0)[:no_of_weights_to_prune]


                        for idx_to_delete in indices_to_delete:
                            flat_masks[idx_to_delete] = 0
                            flat_weights[idx_to_delete] = 0

                        converted_mask[input_index][kernel_index] = flat_masks.reshape(shape)
                        converted_weights[input_index][kernel_index] = flat_weights.reshape(shape)
                back_converted_mask = convert_from_iohw_to_hwio(converted_mask)
                back_converted_weights = convert_from_iohw_to_hwio(converted_weights)
                weights[layer] = back_converted_weights
                weights[layer+2] = back_converted_mask
            self.set_weights(weights)
            return True
        
        def prune_dense_layers_locally(self, ratio):
            
            dense_layer_to_prune = [6, 9, 12]
            weights = self.get_weights()
            for index, weight in enumerate(weights):
                if index in dense_layer_to_prune:
                    shape = weight.shape
                    flat_weights = weight.flatten()
                    flat_mask = weights[index+2].flatten()

                    no_of_weights_to_prune = int(len(flat_weights)*ratio)
                    indices_to_delete = np.abs(flat_weights).argsort()[:no_of_weights_to_prune]
                    for idx_to_delete in indices_to_delete:
                        flat_mask[idx_to_delete] = 0
                        flat_weights[idx_to_delete] = 0
                    mask_reshaped = flat_mask.reshape(shape)
                    weights_reshaped = flat_weights.reshape(shape)
                    weights[index+2] = mask_reshaped
                    weights[index] = weights_reshaped
            self.set_weights(weights)
            return True
        prune_conv_layers_locally(self,ratio)
        prune_dense_layers_locally(self,ratio)
        return
    
    def prune_random_local_struct(self, ratio):
        def prune_conv_layers(conv_layers_to_prune, weights):
            for x in conv_layers_to_prune:

                vals = []
                iohw_weights = convert_from_hwio_to_iohw(weights[x])
                iohw_mask = convert_from_hwio_to_iohw(weights[x+2])
                converted_shape = iohw_weights.shape
                no_of_channels = converted_shape[0]*converted_shape[1]
                no_of_channels_to_prune = int(np.round(ratio * no_of_channels))
                channels = tf.reshape(iohw_weights, (no_of_channels,converted_shape[2],converted_shape[3])).numpy()
                #print(channels)
                non_zero_channels = np.nonzero([np.sum(channel) for channel in channels])[0]
                #print(non_zero_channels)
                no_of_channels_to_prune_left = no_of_channels_to_prune - (len(channels) - len(non_zero_channels))
                random.shuffle(non_zero_channels)
                channels_to_prune = non_zero_channels[:no_of_channels_to_prune_left]
                mask = tf.reshape(iohw_mask, (no_of_channels,converted_shape[2],converted_shape[3])).numpy()

                for channel_to_prune in channels_to_prune:
                    channels[channel_to_prune] = tf.zeros([converted_shape[2],converted_shape[3]])
                    mask[channel_to_prune] = tf.zeros([converted_shape[2],converted_shape[3]])

                reshaped_mask = tf.reshape(mask, converted_shape)
                reshaped_weights = tf.reshape(channels, converted_shape)
                weights[x] = convert_from_iohw_to_hwio(reshaped_weights)
                weights[x+2] = convert_from_iohw_to_hwio(reshaped_mask)
            #self.set_weights(weights)
            return True
        def prune_dense_layers(dense_layers_to_prune, weights):
            for layer_to_prune in dense_layers_to_prune:
                rows = weights[layer_to_prune]
                no_of_rows_to_prune = int(ratio * len(weights[layer_to_prune]))
                non_zero_rows = np.nonzero([np.sum(row) for row in rows])[0]
                no_of_rows_to_prune_left = no_of_rows_to_prune - (len(rows) - len(non_zero_rows))
                random.shuffle(non_zero_rows)
                rows_to_prune = non_zero_rows[:no_of_rows_to_prune_left]
                
                for row_to_prune in rows_to_prune:
                    weights[layer_to_prune][row_to_prune] = tf.zeros(len(weights[layer_to_prune][row_to_prune]))
                    weights[layer_to_prune+2][row_to_prune] = tf.zeros(len(weights[layer_to_prune][row_to_prune]))
            return True
        weights = self.get_weights()
        conv_layers_to_prune = [0,3]
        dense_layers_to_prune = [6,9,12]
        prune_conv_layers(conv_layers_to_prune, weights)
        prune_dense_layers(dense_layers_to_prune, weights)
        self.set_weights(weights)
        return True

    def prune_random_global_struct(self, ratio):
        raise Warning('Not yet implemented')
        return False
    def prune_magnitude_local_struct(self, ratio):
        def prune_conv_layers(conv_layers_to_prune, weights):
            for x in conv_layers_to_prune:

                vals = []
                iohw_weights = convert_from_hwio_to_iohw(weights[x])
                iohw_mask = convert_from_hwio_to_iohw(weights[x+2])
                converted_shape = iohw_weights.shape
                no_of_channels = converted_shape[0]*converted_shape[1]
                no_of_channels_to_prune = int(np.round(ratio * no_of_channels))
                channels = tf.reshape(iohw_weights, (no_of_channels,converted_shape[2],converted_shape[3])).numpy()
                
                mask = tf.reshape(iohw_mask, (no_of_channels,converted_shape[2],converted_shape[3])).numpy()
                for channel in channels:
                    vals.append(tf.math.reduce_sum(tf.math.abs(channel)))
                channels_to_prune = np.argsort(vals)[:no_of_channels_to_prune]

                for channel_to_prune in channels_to_prune:
                    channels[channel_to_prune] = tf.zeros([converted_shape[2],converted_shape[3]])
                    mask[channel_to_prune] = tf.zeros([converted_shape[2],converted_shape[3]])

                reshaped_mask = tf.reshape(mask, converted_shape)
                reshaped_weights = tf.reshape(channels, converted_shape)
                weights[x] = convert_from_iohw_to_hwio(reshaped_weights)
                weights[x+2] = convert_from_iohw_to_hwio(reshaped_mask)
            #self.set_weights(weights)
            return weights
        def prune_dense_layers(dense_layers_to_prune, weights):
            for layer_to_prune in dense_layers_to_prune:
                no_of_rows_to_prune = int(ratio * len(weights[layer_to_prune]))
                vals = []
                for row in weights[layer_to_prune]:
                    vals.append(np.sum(np.abs(row)))
                rows_to_prune = np.argsort(vals)[:no_of_rows_to_prune]
                for row_to_prune in rows_to_prune:

                    weights[layer_to_prune][row_to_prune] = tf.zeros(len(weights[layer_to_prune][row_to_prune]))
                    weights[layer_to_prune+2][row_to_prune] = tf.zeros(len(weights[layer_to_prune][row_to_prune]))
            return weights
        weights = self.get_weights()
        conv_layers_to_prune = [0,3]
        dense_layers_to_prune = [6,9,12]
        weights = prune_conv_layers(conv_layers_to_prune, weights)
        weights = prune_dense_layers(dense_layers_to_prune, weights)
        self.set_weights(weights)
        return True
        
    def prune_magnitude_global_struct(self, ratio):
        def prune_conv_layers(conv_layers_to_prune, weights):
            all_channels = np.empty((0,5,5))
            original_shapes = []
            for layer_to_prune in conv_layers_to_prune:
                iohw_weights = convert_from_hwio_to_iohw(weights[layer_to_prune])
                converted_shape = iohw_weights.shape
                no_of_channels = converted_shape[0]*converted_shape[1]
                channels = tf.reshape(iohw_weights, (no_of_channels,converted_shape[2],converted_shape[3])).numpy()
                all_channels = np.concatenate((all_channels, channels))
            mask = np.ones(all_channels.shape)
            vals = [np.sum(np.abs(channel)) for channel in all_channels]
            no_of_channels_to_prune = int(ratio * len(vals))
            channels_to_prune = np.argsort(vals)[:no_of_channels_to_prune]

            for channel_to_prune in channels_to_prune:
                all_channels[channel_to_prune] = tf.zeros((5,5))
                mask[channel_to_prune] = tf.zeros((5,5))
            z = 0
            for i, layer_to_prune in enumerate(conv_layers_to_prune):
                original_shape = convert_from_hwio_to_iohw(weights[layer_to_prune]).shape
                pruned_layer = tf.reshape(all_channels[z:z + original_shape[0]*original_shape[1]], original_shape)
                pruned_mask = tf.reshape(mask[z:z + original_shape[0]*original_shape[1]], original_shape)
                weights[layer_to_prune] = convert_from_iohw_to_hwio(pruned_layer)
                weights[layer_to_prune + 2] = convert_from_iohw_to_hwio(pruned_mask)
                z = original_shape[0]*original_shape[1]    
            return weights
        
        def prune_dense_layers(dense_layers_to_prune, weights):
            vals = []
            lengths = []
            for layer_to_prune in dense_layers_to_prune:
                lengths.append(weights[layer_to_prune].shape[0])
                vals = vals + [np.sum(np.abs(row)) / len(row) for row in weights[layer_to_prune]]
            no_of_rows_to_prune = int(ratio * len(vals))
            rows_to_prune = np.argsort(vals)[:no_of_rows_to_prune]
            for i, layer_to_prune in enumerate(dense_layers_to_prune):
                for row_to_prune in rows_to_prune:
                    if row_to_prune in range(int(np.sum(lengths[:i])), int(np.sum(lengths[:i+1]))):
                        weights[layer_to_prune][row_to_prune - int(np.sum(lengths[:i]))] = tf.zeros(weights[layer_to_prune][row_to_prune - int(np.sum(lengths[:i]))].shape)
                        weights[layer_to_prune + 2][row_to_prune - int(np.sum(lengths[:i]))] = tf.zeros(weights[layer_to_prune][row_to_prune - int(np.sum(lengths[:i]))].shape)                
            return weights
        weights = self.get_weights()
        conv_layers_to_prune = [0,3]
        dense_layers_to_prune = [6,9,12]
        weights = prune_conv_layers(conv_layers_to_prune, weights)
        weights = prune_dense_layers(dense_layers_to_prune, weights)
        self.set_weights(weights)
        return True

# %% [markdown]
# # Compile and Train Model

# %%
model = CustomConvModel()

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True) ,
              metrics=['accuracy'],
              experimental_run_tf_function=False
              
             )

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)
model.fit(x=x_train,
          y=y_train,
          batch_size=128,
          epochs=1,
          callbacks=[callback],
          validation_data=(x_test, y_test),
         )
#model.save('./saved-models/mini-pipeline-CNN-baseline-model')
# Out:
# 469/469 [==============================] - 1s 3ms/step - loss: 1.6375 - accuracy: 0.8572 - val_loss: 1.5264 - val_accuracy: 0.9412

# %%
model = initialize_base_model(999,'')
train_model(model)
# Out:
# 938/938 [==============================] - 3s 3ms/step - loss: 1.6001 - accuracy: 0.8809 - val_loss: 1.5158 - val_accuracy: 0.9505
# Epoch 1/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.5066 - accuracy: 0.9580 - val_loss: 1.4939 - val_accuracy: 0.9696
# Epoch 2/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4922 - accuracy: 0.9716 - val_loss: 1.4899 - val_accuracy: 0.9730
# Epoch 3/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4864 - accuracy: 0.9762 - val_loss: 1.4844 - val_accuracy: 0.9789
# Epoch 4/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4823 - accuracy: 0.9801 - val_loss: 1.4848 - val_accuracy: 0.9770
# Epoch 5/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4792 - accuracy: 0.9831 - val_loss: 1.4807 - val_accuracy: 0.9811
# Epoch 6/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4772 - accuracy: 0.9847 - val_loss: 1.4839 - val_accuracy: 0.9779
# Epoch 7/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4760 - accuracy: 0.9858 - val_loss: 1.4801 - val_accuracy: 0.9818
# Epoch 8/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4743 - accuracy: 0.9875 - val_loss: 1.4787 - val_accuracy: 0.9828
# Epoch 9/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4739 - accuracy: 0.9878 - val_loss: 1.4770 - val_accuracy: 0.9845
# Epoch 10/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4725 - accuracy: 0.9893 - val_loss: 1.4774 - val_accuracy: 0.9837
# Epoch 11/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4717 - accuracy: 0.9900 - val_loss: 1.4754 - val_accuracy: 0.9861
# Epoch 12/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4711 - accuracy: 0.9907 - val_loss: 1.4779 - val_accuracy: 0.9838
# Epoch 13/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4706 - accuracy: 0.9909 - val_loss: 1.4751 - val_accuracy: 0.9862
# Epoch 14/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4702 - accuracy: 0.9915 - val_loss: 1.4767 - val_accuracy: 0.9849
# Epoch 15/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4702 - accuracy: 0.9914 - val_loss: 1.4752 - val_accuracy: 0.9864
# Epoch 16/500
# 938/938 [==============================] - 3s 3ms/step - loss: 1.4695 - accuracy: 0.9920 - val_loss: 1.4753 - val_accuracy: 0.9858
