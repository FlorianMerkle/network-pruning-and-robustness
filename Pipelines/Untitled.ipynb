# %%
import tensorflow as tf

1e-3 * tf.math.exp(0.1 * (10 - 40))
# Out:
# ---------------------------------------------------------------------------
# _FallbackException                        Traceback (most recent call last)
# ~/anaconda2/envs/master-thesis/lib/python3.8/site-packages/tensorflow/python/ops/gen_math_ops.py in exp(x, name)
#    3564     try:
# -> 3565       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3566         _ctx._context_handle, tld.device_name, "Exp", name, tld.op_callbacks,
#
# _FallbackException: This function does not handle the case of the path where all inputs are not already EagerTensors.
#
# During handling of the above exception, another exception occurred:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-1-8c71ee3a3cac> in <module>
#       1 import tensorflow as tf
#       2
# ----> 3 1e-3 * tf.math.exp(0.1 * (10 - 40))
#
# ~/anaconda2/envs/master-thesis/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
# ...
